# %%
import plotly.express as px

fig = px.line(x=[1, 2], y=[3, 4])

print(fig)
fig
# Out:
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': {'bdata': 'AQI=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AwQ=', 'dtype': 'i1'},
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
df = px.data.iris()

fig = px.line(df, y="sepal_width",)

fig.show()

# %%
df = px.data.iris()

fig = px.line(df, y="sepal_width", line_group='species')

fig.show()

# %%
df = px.data.iris()

fig = px.line(df, y="sepal_width", line_dash='species',
              color='species')

fig.show()

# %%
df = px.data.tips()

fig = px.bar(df, x='day', y="total_bill")

fig.show()

# %%
fig = px.bar(df, x='day', y="total_bill", color='sex',
             facet_row='time', facet_col='sex')

fig.show()

# %%
fig = px.scatter(df, x='total_bill', y="tip")

fig.show()

# %%
fig = px.scatter(df, x='total_bill', y="tip", color='time',
                 symbol='sex', size='size', facet_row='day',
                 facet_col='time')

fig.show()

# %%
fig = px.histogram(df, x="total_bill")

fig.show()

# %%
fig = px.histogram(df, x="total_bill", color='sex',
                   nbins=50, histnorm='percent',
                   barmode='overlay')

fig.show()

# %%
fig = px.pie(df, values="total_bill", names="day")
fig.show()

# %%
fig = px.pie(df, values="total_bill", names="day",
             color_discrete_sequence=px.colors.sequential.RdBu,
             opacity=0.7, hole=0.5)
fig.show()

# %%
fig = px.box(df, x="day", y="tip")

fig.show()

# %%
fig = px.box(df, x="day", y="tip", color='sex',
             facet_row='time', boxmode='group',
             notched=True)

fig.show()

# %%
fig = px.violin(df, x="day", y="tip")

fig.show()

# %%
fig = px.violin(df, x="day", y="tip", color='sex',
                facet_row='time', box=True)

fig.show()

# %%
fig = px.scatter_3d(df, x="total_bill", y="sex", z="tip")

fig.show()

# %%
fig = px.scatter_3d(df, x="total_bill", y="sex", z="tip", color='day', 
                    size='total_bill', symbol='time')

fig.show()

# %%
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import pandas as pd

df = px.data.tips()

plot = go.Figure(data=[go.Scatter(
    x=df['day'],
    y=df['tip'],
    mode='markers',)
])

plot.update_layout(
    updatemenus=[
        dict(buttons=list([
            dict(
                args=["type", "scatter"],
                label="Scatter Plot",
                method="restyle"
            ),
            dict(
                args=["type", "bar"],
                label="Bar Chart",
                method="restyle"
            )
        ]),
            direction="down",
        ),
    ]
)

plot.show()

# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd

df = px.data.tips()

plot = go.Figure(data=[go.Scatter(
    x=df['day'],
    y=df['tip'],
    mode='markers',)
])

plot.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="left",
            buttons=list([
                dict(
                    args=["type", "scatter"],
                    label="Scatter Plot",
                    method="restyle"
                ),
                dict(
                    args=["type", "bar"],
                    label="Bar Chart",
                    method="restyle"
                )
            ]),
        ),
    ]
)

plot.show()

# %%
import plotly.graph_objects as px
import plotly.express as go
import numpy as np

df = go.data.tips()

x = df['total_bill']
y = df['tip']

plot = px.Figure(data=[px.Scatter(
    x=x,
    y=y,
    mode='markers',)
])

plot.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                    step="day",
                    stepmode="backward"),
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
    )
)

plot.show()

# %%
# !pip install dash

# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (6.3.0)
# Requirement already satisfied: importlib-metadata in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from dash) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (2.3.0)
# Requirement already satisfied: packaging in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from requests->dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from requests->dash) (2025.8.3)
# Requirement already satisfied: plotly in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from plotly) (2.3.0)
# Requirement already satisfied: packaging in /home/cadd/Documents/shankar/my_jupyter_env/lib/python3.12/site-packages (from plotly) (25.0)

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

df = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [10, 15, 13, 17, 14]
})

app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.Graph(
        id='example-graph',
        figure=px.scatter(df, x='x', y='y', title='Scatter Plot in Dash')
    )
])

if __name__ == '__main__':
    app.run(debug=True, port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

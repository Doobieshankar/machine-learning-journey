# %%
import pandas as pd
# !pip install openpyxl

# %% [markdown]
# # pivot()

# %%
# read and show the dataset
df_gdp = pd.read_excel('gdp.xlsx')
df_gdp
# Out:
#       unid wbid      country  year        SES       gdppc  yrseduc  popshare  \
# 0        4  AFG  Afghanistan  1970   3.474212   709.00000      NaN  0.003097
# 1        4  AFG  Afghanistan  1920  26.968016   731.75677      NaN  0.003245
# 2        4  AFG  Afghanistan  1990    1.26953   604.00000      NaN  0.002347
# 3        4  AFG  Afghanistan  1960  15.763076   739.00000      NaN  0.003039
# 4        4  AFG  Afghanistan  2000   2.061114   565.00000      NaN  0.003309
# ...    ...  ...          ...   ...        ...         ...      ...       ...
# 2081   716  ZWE     Zimbabwe  1940  52.746567   813.00000      NaN  0.001113
# 2082   716  ZWE     Zimbabwe  2010  27.091389  1388.97300      NaN  0.002074
# 2083   716  ZWE     Zimbabwe  1990   59.11097  2526.07230      NaN  0.002039
# 2084   716  ZWE     Zimbabwe  1900  54.722645   601.00000      NaN  0.000996
# 2085   716  ZWE     Zimbabwe  1960  53.811077   938.00000      NaN  0.001268
#
#       Unnamed: 8  Unnamed: 9
# ...

# %%
# reshape the dataframe with .pivot() 
df_gdp_pivot = df_gdp.pivot_table(index='year', columns="country", values="gdppc")

# %%
df_gdp_pivot
# Out:
# country     Afghanistan     Albania      Algeria      Angola  Argentina  \
# year
# 1880          585.46509   522.00000    819.18604   533.66669   1731.500
# 1890          635.93024   598.00000    923.37207   567.33331   2152.000
# 1900          686.39532   685.00000   1027.55810   601.00000   2756.000
# 1910          736.86047   780.00000   1131.74410   628.69232   3822.000
# 1920          731.75677   861.31250   1201.21620   682.62964   3473.000
# 1930          702.83783   929.57141   1255.81080   747.81482   4080.000
# 1940          673.91895   965.28571   1310.40540   813.00000   4161.000
# 1950          645.00000  1001.00000   1365.00000  1052.00000   4987.000
# 1960          739.00000  1451.00000   2088.00000  1253.00000   5559.000
# 1970          709.00000  2004.00000   2249.00000  1768.00000   7302.000
# 1980          690.00000  2347.00000   3152.00000   961.00000   8206.000
# 1990          604.00000  4557.40820  10238.88400  4806.43020  10833.503
# ...

# %% [markdown]
# # pivot_table()

# %%
# read and show the dataset
df_sales = pd.read_excel('supermarket_sales.xlsx')
df_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# make a pivot table and add an aggregate function
#df_sales.pivot_table(index='Gender',aggfunc='sum').round(1)#error because we cant sum date and time but we can get the mean
df_sales.pivot_table(index='Gender',values=['Invoice ID', 'Branch', 'City', 'Customer type',
       'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
       'Rating'],aggfunc='min').round(1)
# Out:
#        Branch      City Customer type   Invoice ID Payment  \
# Gender
# Female      A  Mandalay        Member  101-81-4070    Cash
# Male        A  Mandalay        Member  101-17-6199    Cash
#
#                   Product line  Quantity  Rating  Tax 5%  Total  Unit price  \
# Gender
# Female  Electronic accessories         1     4.0     0.6   12.7        10.2
# Male    Electronic accessories         1     4.0     0.5   10.7        10.1
#
#         cogs  gross income  gross margin percentage
# Gender
# Female  12.1           0.6                      4.8
# Male    10.2           0.5                      4.8

# %%
df_sales.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df_sales.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000              1000.000000
# mean   2019-02-14 00:05:45.600000   307.58738                 4.761905
# min           2019-01-01 00:00:00    10.17000                 4.761905
# 25%           2019-01-24 00:00:00   118.49750                 4.761905
# 50%           2019-02-13 00:00:00   241.76000                 4.761905
# ...

# %%
# make a pivot table and add an aggregate function
df_sales.pivot_table(index='Gender',
                     values=['Unit price','Quantity','Tax 5%','Total','cogs','gross margin percentage','gross income','Rating'],
                     aggfunc='sum').round(1)
# Out:
#         Quantity  Rating  Tax 5%     Total  Unit price      cogs  \
# Gender
# Female      2869  3489.2  7994.4  167882.9     27687.2  159888.5
# Male        2641  3483.5  7384.9  155083.8     27984.9  147698.9
#
#         gross income  gross margin percentage
# Gender
# Female        7994.4                   2385.7
# Male          7384.9                   2376.2

# %%
# make a pivot table and add an aggregate function
df_sales.pivot_table(index=['Gender','Branch'],
                     values=['Unit price','Quantity','Tax 5%','Total','cogs','gross margin percentage','gross income','Rating','Date'],
                     aggfunc='mean').round(1)
# Out:
#                                        Date  Quantity  Rating  Tax 5%  Total  \
# Gender Branch
# Female A      2019-02-15 22:57:23.478260992       5.6     6.8    15.8  330.9
#        B      2019-02-12 03:42:13.333333248       5.6     6.9    15.6  326.7
#        C      2019-02-10 20:53:55.955056128       5.9     7.2    16.5  346.5
# Male   A      2019-02-14 03:13:04.357541888       5.3     7.2    14.1  295.7
#        B      2019-02-16 10:26:49.411764736       5.3     6.8    14.9  313.3
#        C      2019-02-14 17:07:12.000000000       5.2     7.0    15.5  325.9
#
#                Unit price   cogs  gross income  gross margin percentage
# Gender Branch
# Female A             56.1  315.1          15.8                      4.8
#        B             54.2  311.2          15.6                      4.8
#        C             55.5  330.0          16.5                      4.8
# Male   A             53.6  281.6          14.1                      4.8
# ...

# %%
# make a pivot table, add an aggregate function and select some columns 
df_sales.pivot_table(index='Gender',
                     values=['Quantity', 'Total'],
                     aggfunc='sum').round(1)
# Out:
#         Quantity     Total
# Gender
# Female      2869  167882.9
# Male        2641  155083.8

# %%
# make a pivot tables that says how much male and female spend in each category
df_sales.pivot_table(index='Gender',
                     columns='Product line',
                     values='Total',
                     aggfunc='sum').round(1)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                       27102.0              30437.4             33170.9
# Male                         27235.5              23868.5             22973.9
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                  18561.0             30036.9            28574.7
# Male                    30632.8             23825.0            26548.1

# %%
# make a pivot tables that says how much male and female spend in each category
df_sales.pivot_table(index=['Gender','Branch'],
                     columns='Product line',
                     values='Total',
                     aggfunc='sum').round(1)
# Out:
# Product line   Electronic accessories  Fashion accessories  \
# Gender Branch
# Female A                       9966.3               9836.2
#        B                       8166.5               9081.5
#        C                       8969.2              11519.7
# Male   A                       8350.8               6496.3
#        B                       8884.9               7331.8
#        C                       9999.8              10040.4
#
# Product line   Food and beverages  Health and beauty  Home and lifestyle  \
# Gender Branch
# Female A                   6999.8             5714.9             12636.8
#        B                  10510.0             6400.3              9557.1
#        C                  15661.2             6445.7              7842.9
# Male   A                  10163.3             6882.9              9780.4
#        B                   4704.9            13580.3              7992.0
#        C                   8105.7            10169.6              6052.6
#
# ...
